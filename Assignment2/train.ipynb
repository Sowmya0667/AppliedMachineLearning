# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (3.9.0)
# Requirement already satisfied: mlflow-skinny==3.9.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (1.18.4)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (46.0.5)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: huey<3,>=2.5.4 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (2.2.6)
# Requirement already satisfied: pandas<3 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: skops<1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (2.0.46)
# Requirement already satisfied: waitress<4 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.88.0)
# Requirement already satisfied: fastapi<1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.129.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.33.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from mlflow-skinny==3.9.0->mlflow) (0.40.0)
# Requirement already satisfied: Mako in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: pywin32>=304 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4->mlflow) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.3.1)
# Requirement already satisfied: pycparser in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)
# Requirement already satisfied: colorama in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.9.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (2.48.0)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.9.0->mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow) (0.60b1)
# Requirement already satisfied: wcwidth in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from prettytable>=3.9->skops<1->mlflow) (0.2.14)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (2025.11.12)
# Requirement already satisfied: h11>=0.8 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.6.2->starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\sowmy\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.6.2)
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: C:\Users\sowmy\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### **Import Libraries**

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import average_precision_score

# %% [markdown]
# ### **Set MLflow Tracking**

# %%
import mlflow
import mlflow.sklearn
import os

os.makedirs("mlruns", exist_ok=True)
mlflow.set_tracking_uri("file:./mlruns")


mlflow.set_experiment("Spam Detection Benchmark Models")
# Out:
# c:\Users\sowmy\anaconda3\lib\site-packages\mlflow\tracking\_tracking_service\utils.py:178: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri, store_uri)
# 2026/02/14 23:29:01 INFO mlflow.tracking.fluent: Experiment with name 'Spam Detection Benchmark Models' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///c:/Users/sowmy/Downloads/SEM4/AML/Assignment2/mlruns/663893061351406484', creation_time=1771091941507, experiment_id='663893061351406484', last_update_time=1771091941507, lifecycle_stage='active', name='Spam Detection Benchmark Models', tags={}>

# %% [markdown]
# ### **Load Data**

# %%
train_df = pd.read_csv("train.csv")
val_df = pd.read_csv("validation.csv")
test_df = pd.read_csv("test.csv")

# %% [markdown]
# ### **Add Extra Text Features**

# %%
def add_text_features(df):
    df["num_characters"] = df["Message"].fillna("").apply(len)
    df["num_words"] = df["Message"].fillna("").apply(lambda x: len(x.split()))
    df["num_sentences"] = df["Message"].fillna("").apply(
        lambda x: x.count('.') + x.count('!') + x.count('?')
    )
    return df

# %%
train_df = add_text_features(train_df)
val_df = add_text_features(val_df)
test_df = add_text_features(test_df)

# %%
train_df.head()
# Out:
#    Label                                            Message  num_characters  \
# 0      0                                             ü come               6
# 1      0  forgot work today wan na chat thing ok drop te...              91
# 2      0                                            problem               7
# 3      0                           think chennai well settl              24
# 4      0                  yup havent want go yoga call book              33
#
#    num_words  num_sentences
# 0          2              0
# 1         19              0
# 2          1              0
# 3          4              0
# 4          7              0

# %% [markdown]
# ### **TF-IDF Vectorization**

# %%
train_df["Message"] = train_df["Message"].fillna("").astype(str)
val_df["Message"] = val_df["Message"].fillna("").astype(str)
test_df["Message"] = test_df["Message"].fillna("").astype(str)

# %%
tfidf = TfidfVectorizer(max_features=3000)

X_train_text = tfidf.fit_transform(train_df["Message"])
X_val_text = tfidf.transform(val_df["Message"])
X_test_text = tfidf.transform(test_df["Message"])

# %% [markdown]
# ### **Combine Extra Features**

# %%
def combine_features(X_text, df):
    extra = df[["num_characters", "num_words", "num_sentences"]].values
    return hstack([X_text, extra])

# %%
X_train = combine_features(X_train_text, train_df)
X_val = combine_features(X_val_text, val_df)
X_test = combine_features(X_test_text, test_df)

y_train = train_df["Label"]
y_val = val_df["Label"]
y_test = test_df["Label"]

# %% [markdown]
# ### **Models**

# %%
models = { 
    "MultinomialNB": MultinomialNB(),
    
    "LogisticRegression": LogisticRegression(
        C=10,
        max_iter=1000,
        class_weight="balanced",
        random_state=42
    ),
    
    "RandomForestClassifier": RandomForestClassifier(
        n_estimators=200,
        max_depth=None,
        random_state=42,
        n_jobs=-1
    )
}

# %% [markdown]
# ### **MLflow Experiment Setup**

# %%
mlflow.set_experiment("Assignment2_Model_Versioning")
# Out:
# 2026/02/14 23:34:15 INFO mlflow.tracking.fluent: Experiment with name 'Assignment2_Model_Versioning' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///c:/Users/sowmy/Downloads/SEM4/AML/Assignment2/mlruns/309911367380612686', creation_time=1771092255996, experiment_id='309911367380612686', last_update_time=1771092255996, lifecycle_stage='active', name='Assignment2_Model_Versioning', tags={}>

# %% [markdown]
# ### **Train, Track, and Register Models**

# %%
val_scores = {}

for model_name, model in models.items():
    
    with mlflow.start_run(run_name=model_name):
        
        # Train
        model.fit(X_train, y_train)
        
        # Validation probabilities
        y_val_proba = model.predict_proba(X_val)[:, 1]
        val_aucpr = average_precision_score(y_val, y_val_proba)
        
        # Test probabilities
        y_test_proba = model.predict_proba(X_test)[:, 1]
        test_aucpr = average_precision_score(y_test, y_test_proba)
        
        # Log parameters
        mlflow.log_params(model.get_params())
        
        # Log metrics
        mlflow.log_metric("val_AUCPR", val_aucpr)
        mlflow.log_metric("test_AUCPR", test_aucpr)
        
        # Log model
        mlflow.sklearn.log_model(model, "model")
        
        # Register model
        model_uri = f"runs:/{mlflow.active_run().info.run_id}/model"
        mlflow.register_model(model_uri, model_name)
        
        val_scores[model_name] = val_aucpr
        
        print(f"{model_name} - Validation AUCPR: {val_aucpr}")
# Out:
# 2026/02/14 23:34:18 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# c:\Users\sowmy\anaconda3\lib\site-packages\mlflow\models\model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format.
#   flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# c:\Users\sowmy\anaconda3\lib\site-packages\mlflow\tracking\_model_registry\utils.py:216: FutureWarning: The filesystem model registry backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri)
# Successfully registered model 'MultinomialNB'.
# 2026/02/14 23:34:48 WARNING mlflow.tracking._model_registry.fluent: Run with id 1c48a53347684eb1ad903ffe7cb2759c has no artifacts at artifact path 'model', registering model based on models:/m-6839fb879ba44767ab7fcb60c1b6c9f1 instead
# Created version '1' of model 'MultinomialNB'.
# MultinomialNB - Validation AUCPR: 0.8092735861467902
# 2026/02/14 23:34:49 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# c:\Users\sowmy\anaconda3\lib\site-packages\mlflow\models\model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format.
#   flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# Successfully registered model 'LogisticRegression'.
# 2026/02/14 23:34:56 WARNING mlflow.tracking._model_registry.fluent: Run with id e3da9b532a5649419bb2b28a1dbdc49e has no artifacts at artifact path 'model', registering model based on models:/m-5fe8e40f47a444228917204604eb8f12 instead
# Created version '1' of model 'LogisticRegression'.
# LogisticRegression - Validation AUCPR: 0.9542030846367953
# 2026/02/14 23:34:57 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# c:\Users\sowmy\anaconda3\lib\site-packages\mlflow\models\model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format.
#   flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# Successfully registered model 'RandomForestClassifier'.
# 2026/02/14 23:35:05 WARNING mlflow.tracking._model_registry.fluent: Run with id bfa1cc225248432997cc637e31187d9f has no artifacts at artifact path 'model', registering model based on models:/m-8a6ea6a9c8df4904a6247f79fe92c5f0 instead
# Created version '1' of model 'RandomForestClassifier'.
# RandomForestClassifier - Validation AUCPR: 0.9633827776825854

# %% [markdown]
# ### **Checkout and Print AUCPR for All 3 Models**

# %%
print("\nModel Selection Metric (Validation AUCPR):\n")

for name, score in val_scores.items():
    print(f"{name}: {score}")
# Out:
# Model Selection Metric (Validation AUCPR):
#
# MultinomialNB: 0.8092735861467902
# LogisticRegression: 0.9542030846367953
# RandomForestClassifier: 0.9633827776825854

# %% [markdown]
# ### **Select Best Model**

# %%
best_model = max(val_scores, key=val_scores.get)

print("\nBest Model Based on Validation AUCPR:", best_model)
# Out:
# Best Model Based on Validation AUCPR: RandomForestClassifier
